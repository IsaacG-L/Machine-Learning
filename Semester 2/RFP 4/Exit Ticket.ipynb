# %%
import pandas as pd
import seaborn as sns
import json

# %%
with open("heyohriver.json", 'r') as file:
    data = json.load(file)

# %%
data.keys()
# Out:
# dict_keys(['collaborative', 'description', 'external_urls', 'followers', 'href', 'id', 'images', 'name', 'owner', 'primary_color', 'public', 'snapshot_id', 'tracks', 'type', 'uri'])

# %%
data['tracks']
# Out:
# {'href': 'https://api.spotify.com/v1/playlists/1zkcrdojxO7N3QiDaG28wJ/tracks?offset=0&limit=100&additional_types=track',
#  'items': [{'added_at': '2024-04-20T02:58:19Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1225630715'},
#     'href': 'https://api.spotify.com/v1/users/1225630715',
#     'id': '1225630715',
#     'type': 'user',
#     'uri': 'spotify:user:1225630715'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': None,
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
# ...

# %%
records = data["tracks"]

# %%
#df = pd.DataFrame(records)

# %%
type(data['tracks'])
# Out:
# dict

# %%
#records

# %%
#records['items']

# %%
df = pd.DataFrame(records['items'])

# %%
df = pd.json_normalize(records, sep='_')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   href      1 non-null      object
#  1   items     1 non-null      object
#  2   limit     1 non-null      int64
#  3   next      0 non-null      object
#  4   offset    1 non-null      int64
#  5   previous  0 non-null      object
#  6   total     1 non-null      int64
# dtypes: int64(3), object(4)
# memory usage: 188.0+ bytes

# %%
#records['items']

# %%
#df = pd.concat([df.drop(columns=["tracks"]), df["tracks"].apply(pd.Series)], axis=1)

# %%
track_list = records["items"]  # Extract the list from the dictionary

if isinstance(track_list, list):  # Ensure it's actually a list
    df = pd.DataFrame(track_list)  # Convert the list to a DataFrame
    print(df.head())  # Show first few rows
else:
    print("Error: 'items' is not a list")
# Out:
#                added_at                                           added_by  \
# 0  2024-04-20T02:58:19Z  {'external_urls': {'spotify': 'https://open.sp...
# 1  2024-04-20T02:58:27Z  {'external_urls': {'spotify': 'https://open.sp...
# 2  2024-04-20T02:59:37Z  {'external_urls': {'spotify': 'https://open.sp...
# 3  2024-04-20T02:59:48Z  {'external_urls': {'spotify': 'https://open.sp...
# 4  2024-04-20T03:00:28Z  {'external_urls': {'spotify': 'https://open.sp...
#
#    is_local primary_color                                              track  \
# 0     False          None  {'preview_url': None, 'available_markets': ['A...
# 1     False          None  {'preview_url': None, 'available_markets': ['M...
# 2     False          None  {'preview_url': None, 'available_markets': ['A...
# 3     False          None  {'preview_url': None, 'available_markets': ['A...
# 4     False          None  {'preview_url': None, 'available_markets': ['U...
#
#   video_thumbnail
# 0   {'url': None}
# ...

# %%
records
# Out:
# {'href': 'https://api.spotify.com/v1/playlists/1zkcrdojxO7N3QiDaG28wJ/tracks?offset=0&limit=100&additional_types=track',
#  'items': [{'added_at': '2024-04-20T02:58:19Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1225630715'},
#     'href': 'https://api.spotify.com/v1/users/1225630715',
#     'id': '1225630715',
#     'type': 'user',
#     'uri': 'spotify:user:1225630715'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': None,
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
# ...
